# %%
# %run ../load_data.ipynb
# Out:
# C:\Users\jmp08\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:237: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# C:\Users\jmp08\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\jmp08\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
import xgboost

# %%
trainData, validData = train_test_split(train, test_size = .3)

trainFeature = trainData.drop("class", axis = "columns")
trainTarget = trainData["class"]

validFeature = validData.drop("class", axis = "columns")
validTarget = validData["class"]

# %%
tree = xgboost.XGBClassifier(objective = "softprob", n_estimators = 400, n_jobs = -1, learning_rate = 0.1, max_depth = 5)
tree.fit(trainFeature, trainTarget, eval_set = [(validFeature, validTarget)])
# Out:
# [0]	validation_0-merror:0.107906
# [1]	validation_0-merror:0.106271
# [2]	validation_0-merror:0.105996
# [3]	validation_0-merror:0.103305
# [4]	validation_0-merror:0.102364
# [5]	validation_0-merror:0.102133
# [6]	validation_0-merror:0.101554
# [7]	validation_0-merror:0.101134
# [8]	validation_0-merror:0.100339
# [9]	validation_0-merror:0.100295
# [10]	validation_0-merror:0.09895
# [11]	validation_0-merror:0.098573
# [12]	validation_0-merror:0.09798
# [13]	validation_0-merror:0.098009
# [14]	validation_0-merror:0.097937
# [15]	validation_0-merror:0.097532
# [16]	validation_0-merror:0.097098
# [17]	validation_0-merror:0.097054
# [18]	validation_0-merror:0.096461
# [19]	validation_0-merror:0.096244
# [20]	validation_0-merror:0.09581
# [21]	validation_0-merror:0.095448
# [22]	validation_0-merror:0.09513
# [23]	validation_0-merror:0.094754
# [24]	validation_0-merror:0.094696
# [25]	validation_0-merror:0.094059
# [26]	validation_0-merror:0.093495
# [27]	validation_0-merror:0.093567
# ...

# %%
result = tree.predict_proba(testFeature)
sum(np.argmax(result, axis = 1) == np.argmax(testTarget, axis = 1)) / len(testTarget)
# Out:
# 0.9252205014237099

# %%
train.shape
# Out:
# (230384, 19)
